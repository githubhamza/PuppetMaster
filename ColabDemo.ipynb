# %% [markdown]
# **Setting up environment** 😀

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.7
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
# !sudo update-alternatives --config python3
# !sudo apt-get install python3.7-distutils
# !apt-get install python3-pip
# !python -m pip install --upgrade pip --user
from IPython.display import clear_output
clear_output()
print("Your Environment is Set!")

# %% [markdown]
# **Installing Requirements** 😀

# %%
# !pip install torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu116
# !pip install ffmpeg-python==0.2.0
# !pip install imageio==2.28.1
# !pip install imageio-ffmpeg==0.4.8
# !pip install matplotlib==3.5.3
# !pip install numpy==1.21.5
# !pip install PyYAML==6.0
# !pip install tqdm==4.65.0
# !pip install imageio==2.28.1
# !pip install scikit-image==0.18
# !pip install sklearn==1.0.2
# !pip install pandas==1.3.5
# !pip install streamlit==1.22.0
# !pip install imageio[ffmpeg]
# !pip install imageio[async]
clear_output()
print("Requirements Installed!!")

# %%
# !git clone https://github.com/xinntao/Real-ESRGAN.git
clear_output()
# %cd Real-ESRGAN

# %%
# !pip install basicsr
# !pip install facexlib
# !pip install gfpgan
# !pip install pillow==9.5.0
# !pip install scikit-learn==1.0.2
# !pip install gdown
# !python setup.py develop
# %cd ..
clear_output()
print("Requirements Installed!!")

# %% [markdown]
# **Importing PuppetMaster**

# %%
# !gdown 1uiQbe7PWS73Afg9tXVOF8pgR10pV7BJu
# !unzip PuppetMaster.zip -d PuppetMaster
# %cd PuppetMaster/PuppetMaster
clear_output()
print("Download & Extract Complete")
# %ls

# %% [markdown]
# **Running Demo**
# *   Execute The Cell
# *   Open Link
# *   Copy External URL without port number
# *   Paste URL in textbox of URL opened

# %%
# !streamlit run front.py & npx localtunnel --port 8501
clear_output()
